# %% [markdown]
# # Module 4: Final Project
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/4_Final_Project.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2F4_Final_Project.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## With all you've learned...
# <img src="https://media.makeameme.org/created/no-pressure-5b8539.jpg" alt="It's your turn" width=400/>

# %% [markdown]
# ## Project #3 (40% toward your final grade).
#
# Do whatever you want.
#
# A list of reputable data sources are provided below, but you are encouraged to explore additional sources and topics you like.
#
# ### You need to do a pitch presentation and a final presentation:
# * **Pitch presentation:** 1 slide (no animation), 1.5 min, to introduce your project idea.
#     - General info: name, project title.
#     - Data: sources, size.
#     - Methodology: tools, analyses, expected results.
# * **Final presentation:** 2 slides, 3 min, to convey the key findings.
#     - Slide 1: general info, overall methodology.
#     - Slide 2: representative figures, key takeaways.
#
# ### You need to submit:
# * Slides for pitch and final presentation.
# * All scripts for data processing and associated data files.
# * A short report including:
#    - A cover page with your name, date, and class/project name.
#    - Methods: sufficient details for others to regenerate your work with your scripts/data files.
#    - Results & Discussion: generated figures and a short discussion on what you learn from the figures.

# %% [markdown]
# ## Select Data Sources
#
# * [Our World in Data](https://ourworldindata.org/): Research and data to make progress against the world’s largest problems.
# * [Data.gov](https://data.gov/): The Home of the U.S. Government's Open Data.
# * Data from Federal/State governments:
#     - [U.S. Census Bureau](https://data.census.gov/)
#     - [U.S. Geological Survey](https://www.usgs.gov/products)
#     - National Oceanic and Atmospheric Administration [Climate Data Online](https://www.ncei.noaa.gov/cdo-web/).
#     - [U.S. Environmental Protection Agency](https://www.waterqualitydata.us/)
#     - [U.S. Department of Agriculture](https://www.usda.gov/about-usda/reports-and-data/data)
#     - [U.S. Department of Energy](https://www.energy.gov/data/open-energy-data)
# * Other reputable sources:
#     - [National Ecological Observatory Network](https://data.neonscience.org/)
#     - *[scientific data](https://www.nature.com/sdata/)* (peer-reviewed journal by Springer Nature)
#     - [Kaggle](https://www.kaggle.com/datasets)
