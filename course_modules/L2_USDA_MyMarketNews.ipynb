# %% [markdown]
# # Lecture 2: USDA My Market News Project
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/L2_Data_Center_Project.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2FL2_Data_Center_Project.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## My Market News – Your Source for Ag Data
# <a target="_blank" href="https://mymarketnews.ams.usda.gov/">
#   <img src="https://mymarketnews.ams.usda.gov/sites/default/files/inline-images/Slide%20%233%20July%202018_730x280.jpg" alt="MMN"/>
# </a>

# %% [markdown]
# ### Step 1. Go to Market News API (application programming interface)
# <img src="https://mymarketnews.ams.usda.gov/sites/default/files/inline-images/apiMN.jpg" alt="market news API"/>

# %% [markdown]
# ### Step 2. Register an account via login.gov
# <img src="https://secure.login.gov/assets/user-access-9df0c67e.svg" alt="login.gov">

# %% [markdown]
# ### Step 3. Follow the instruction to generate the API key
# <img src="../images/L2_api_key.png" alt="API key">

# %% [markdown]
# ### Step 4. Download the Excel sample spreadsheet
# <img src="../images/L2_sample_spreadsheet.png" alt="sample spreadsheet">

# %% [markdown]
# ### Step 5. Authenicate the sample spreadsheet
# <img src="../images/L2_authenication.png" alt="authenication">

# %% [markdown]
# ### Step 5. Authenicate the sample spreadsheet
# <br>
# Setting can be updated in the Data ribbon -> Get Data -> Data Source Settings
# <img src="../images/L2_data_source_settings.png" alt="data source settings">

# %% [markdown]
# ### Step 6. Refresh data
# <br>
# This is to make sure you successfully authenicate the spreadsheet.
# <img src="../images/L2_refresh_data.png" alt="refresh data">

# %% [markdown]
# ### Step 7. In-class demonstration: cheese
#
# <img src="https://falmouthfarmersmarket.com/wp-content/uploads/2024/07/cheese.jpg" alt="say cheese">
#
# Suppose you want to start a business in cheese and you'd like to use to data to:
# * Learn the historic trend of cheese prices price
# * See if price varies with:
#   - Region
#   - Season/Quarter
#   - Cheese type
# * See if you could use one group of price to predict another group
# * See if you could build a model to forecast future price

# %% [markdown]
# - ML model?

# %% [markdown]
# ## Project #1 (20% toward your final grade).
#
# From the list of available reports, choose one or more reports you like, use different methods to extract data, perform statistical analyses, test your hypotheses, and build predict models.
#
# **Requirements:**
# * These reports cannot be the same as the existing ones in the sample spreadsheet.
# * You must use Excel and at least one programming language.
# * You need to
# * You must demonstrate the ability to:
#   - Import/export data
#   - Filter/sort data
#   - Statistical analysis (e.g., description, correlation, histogram, box)
#   - Build predictive models
#
# **You need to submit:**
# * Data sheets containing the raw data for the reports you selected.
# * All scripts for data processing.
# * A short report including:
#    - A cover page with your name, date, and class/project name.
#    - Methods: sufficient details for others to regenerate your work with your scripts/data files.
#    - Results & Discussion: generated figures and a short discussion on what you learn from the figures.
