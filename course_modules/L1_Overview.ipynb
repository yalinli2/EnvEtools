# %% [markdown]
# # Lecture 1: Course Overview
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/L1_Overview.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2FL1_Overview.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# ### About me
# * **Yalin Li**, Assistant Profess, CEE
# * **Office:** Weeks 328A
# * **Email:** yalin.li@rutgers.edu
# * **Website:** [yalinli.group](https://yalinli.group)

# %% [markdown]
# ### About you
# * Name
# * Experiences about software tools
# * Expectation of the class
# * Something about you that you want to share

# %% [markdown]
# ### About the course
# * **What:** get data, manipulate date, use data, generate data, analyze data.
# * **Where:** materials on Canvas, [GitHub](https://github.com/yalinli2/EnvEtools), & internet.
# * **How:** Project-based: practice, practice, practice.

# %% [markdown]
# ### Syllabus
# -> Go to Canvas

# %% [markdown]
# ## 2. Why do you need this course?

# %% [markdown]
# ### Moneyball
#
# TODO: find a good short video

# %% [markdown]
# ### How data analytics is revolutionizing the NBA
# <a target="_blank" href="https://d3.harvard.edu/platform-digit/submission/how-data-analytics-is-revolutionizing-the-nba">
#   <img src="https://d3.harvard.edu/platform-digit/wp-content/uploads/sites/2/2020/04/Cover-5-900x200.png" alt="NBA Data Analytics"/>
# </a>

# %% [markdown]
# ### New ideas and tools in Environmental Science and Engineering
#
# <a target="_blank" href="https://pubs.acs.org/doi/full/10.1021/acs.est.1c01339">
#   <img src="https://pubs.acs.org/cms/10.1021/acs.est.1c01339/asset/images/large/es1c01339_0002.jpeg" alt="ML in ESE"/>
# </a>

# %% [markdown]
# ### 3. What tools are we going to learn?
#
# ![download.jpg](attachment:fd23831c-51c6-4e8b-9d7c-0ea2d6ced320.jpg)

# %% [markdown]
# * Excel/spreadsheet (GUI tools)
# * MATLAB/Python (programming)
# * GIS (geospatial)

# %% [markdown]
# ### 4. What's considered "success" for this course?
# <img src="https://preview.redd.it/its-all-just-functions-v0-ck5ovob0mgv81.jpg?width=640&crop=smart&auto=webp&s=092c2b617d86622431f2ceb28b9ca0a9cbfd4612" alt="computer meme"/>

# %% [markdown]
# * Feel comfortable with tools.

# %% [markdown]
# <img src="https://datasciencedojo.com/wp-content/uploads/meme-5.jpg.webp" alt="tool meme"/>

# %% [markdown]
# * And the ever-growing number of tools...

# %% [markdown]
# ![image.png](attachment:1f816e0d-83aa-4d49-8b12-dcbec61e0179.png)

# %% [markdown]
# ## LAPTOP TO CLASS EVERY LECTURE
# Or let Prof. Li if you have special situations.
