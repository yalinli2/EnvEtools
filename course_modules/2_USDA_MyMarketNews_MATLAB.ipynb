# %% [markdown]
# # Module 2: USDA My Market News Project - MATLAB
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/2_USDA_MyMarketNews_MATLAB.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2F2_USDA_MyMarketNews_MATLAB.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## MATLAB
#
# MATLAB is also a widely used programming tool, although it is proprietary.
#
# Once you know how to use Python, MATLAB (or any other programming languages) isn't that hard to learn.
#
# Although not a focus in this course, but we will also look at how MATLAB can be used to achieve the same goals as Excel and Python.
#
# We will use the online version of MATLAB. You can access it with your Rutgers account [here](https://matlab.mathworks.com).

# %% [markdown]
# ## Demo

# %% [markdown]
#  ### Windows
#  * Menu bar
#  * Files
#  * Workspace
#    - clear
#  * Editor
#    - How to run
#    - Sections
#    - ;
#  * Command/Console
#    - clc

# %% [markdown]
# ### Navigate MATLAB
# Data needs to be upload to [MATLAB Drive](https://drive.mathworks.com/), or directly upload in MATLAB interface's file window.
#
# <img src='../images/2_matlab_drive.png' alt='MATLAB Drive' width=300>

# %% [markdown]
# ### Import Data
# * Read data
# * Read data with headers
# * Combine sheets from one excel together

# %% [markdown]
# ### Plot Price Trend
# * Plot price for all Process American cheese in the West
# <img src='../images/2_matlab_price_trend.png' alt='price trend' width=400>

# %% [markdown]
# ### Plot Price by Type
#
# * Create a bar plot for average prices
# * Make a grouped bar plot for the average min and max prices
#
# <img src='../images/2_matlab_price_by_type.png' alt='price by type' width=400>

# %% [markdown]
# ### Plot Price Statistics
# * Make box plots of cheese min and max prices by cheese type
# <img src='../images/2_matlab_stats_box.png' alt='boxes' width=400>

# %% [markdown]
# * Make histograms of price_min and price_max for different types of cheese
# * For each type of the cheese, make histograms of price_min and price_max
# <img src='../images/2_matlab_stats_hist.png' alt='histograms' width=600>
