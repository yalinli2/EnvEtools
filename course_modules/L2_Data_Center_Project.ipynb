# %% [markdown]
# # Lecture 2: The Data Center Project
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/L2_Data_Center_Project.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2FL2_Data_Center_Project.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## Data centers are growing exponentially
# <a target="_blank" href="https://bipartisanpolicy.org/report/electricity-demand-growth-and-data-centers/">
#   <img src="../images/L2_data_center_report_cover.png" alt="data center report cover"/>
# </a>

# %% [markdown]
# <img src="../images/L2_VA_statement.png" alt="VA statement"/>
#
# <img src="../images/L2_PJM_forecast.png" alt="PJM forecast"/>
#
# <img src="../images/L2_PJM_peak_demand.png" alt="PJM peak demand"/>

# %% [markdown]
# <img src="../images/L2_GA_forecast.png" alt="GA forecast"/>

# %% [markdown]
# <img src="../images/L2_global_data_center_electricity.png" alt="global data center electricity"/>

# %% [markdown]
# <img src="../images/L2_global_projected_growth_rate.png" alt="global projected growth rate"/>

# %% [markdown]
# ## GenAI and the water-energy nexus
#
# <a target="_blank" href="https://www.cleanegroup.org/webinar/local-strategies-for-data-center-reform/">
#   <img src="../images/L2_data_center_webinar.png" alt="data center webinar"/>
# </a>
#
# <a target="_blank" href="https://youtu.be/-5U8BbN-9B8?si=aHdmWXM7qJFBxCbt">
#   <img src="https://www.cleanegroup.org/wp-content/plugins/wp-rocket/assets/img/youtube.png" alt="data center video"/>
# </a>

# %% [markdown]
# ## How to quantitatively demonstrate the impacts of data centers on water/energy availability?

# %% [markdown]
# <img src="../images/L2_data_center_project.png" alt="data center project"/>

# %% [markdown]
# ## How could we do this?

# %% [markdown]
# 1. Find data on data centers

# %% [markdown]
# 2. Find data on water availability
#
# * How to quantify water availability?

# %% [markdown]
# 3. Find data on energy availability/emission
#
# * How to quantify energy availability?

# %% [markdown]
# 4. Super-impose them together

# %% [markdown]
# ## Wait, you said you would teach the tools!
# <img src="https://media2.giphy.com/media/v1.Y2lkPTc5MGI3NjExa2trZWIxa2x5NDFyMXZvcWc5cWc2NnFsODdmcmV0bXd5aWViZWtmcCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/1EghTrigJJhq8/giphy.gif" alt="panic meme"/>

# %% [markdown]
# I will go through how to find data, extract/export data, organize data, analyze data, and visualize data

# %% [markdown]
# Then it'll be your turn

# %% [markdown]
# <img src="https://media1.tenor.com/m/e0LeCIcG5IkAAAAd/evil-smile.gif"/>
