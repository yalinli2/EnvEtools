# %% [markdown]
# # Lecture 4: Final Project
#
# <a target="_blank" href="https://colab.research.google.com/github/yalinli2/EnvEtools/blob/main/course_modules/L3_Data_Center_Project.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <a target="_blank" href="https:///mybinder.org/v2/gh/yalinli2/EnvEtools/main?urlpath=%2Fdoc%2Ftree%2Fcourse_modules%2FL3_Data_Center_Project.ipynb">
#   <img src="https://mybinder.org/badge_logo.svg" alt="Open In Binder"/>
# </a>

# %% [markdown]
# ## Data centers are growing exponentially
# <a target="_blank" href="https://bipartisanpolicy.org/report/electricity-demand-growth-and-data-centers/">
#   <img src="../images/L3_data_center_report_cover.png" alt="data center report cover"/>
# </a>

# %% [markdown]
# ## Project #3 (40% toward your final grade).
#
# Do whatever you want.
#
# You need to submit:
# * All scripts for data processing and associated data files.
# * A short report including:
#    - A cover page with your name, date, and class/project name.
#    - Methods: sufficient details for others to regenerate your work with your scripts/data files.
#    - Results & Discussion: generated figures and a short discussion on what you learn from the figures.

# %% [markdown]
# ## Potential Topics & Resources
#
# Do whatever you want.
#
# You need to submit:
# * All scripts for data processing and associated data files.
# * A short report including:
#    - A cover page with your name, date, and class/project name.
#    - Methods: sufficient details for others to regenerate your work with your scripts/data files.
#    - Results & Discussion: generated figures and a short discussion on what you learn from the figures.
